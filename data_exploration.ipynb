# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
signals=pd.read_csv("wind-farm-1-signals-training.csv",sep=";")
failures=pd.read_csv("wind-farm-1-failures-training.csv",sep=";")
logs=pd.read_csv("wind-farm-1-logs-training.csv",sep=";")
metmast=pd.read_csv("wind-farm-1-metmast-training.csv",sep=";")
powercurve=pd.read_csv("Power_curve.csv",sep=",")

# %% [markdown]
# # Powercurve

# %%
powercurve
# Out:
#     Wind speed (m/s)  Power (kW)
# 0                4.0          89
# 1                4.5         142
# 2                5.0         204
# 3                5.5         279
# 4                6.0         368
# 5                6.5         470
# 6                7.0         594
# 7                7.5         736
# 8                8.0         896
# 9                8.5        1069
# 10               9.0        1247
# 11               9.5        1428
# 12              10.0        1599
# 13              10.5        1753
# 14              11.0        1881
# 15              11.5        1951
# 16              12.0        1981
# 17              12.5        1994
# 18              13.0        1998
# 19              13.5        2000
# 20              14.0        2000
# 21              14.5        2000
# 22              15.0        2000
# 23              15.5        2000
# 24              16.0        2000
# 25              16.5        2000
# 26              17.0        2000
# ...

# %%
sns.lineplot(powercurve.iloc[:,0],powercurve.iloc[:,1])

# %% [markdown]
# # Signals

# %%
signals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434145 entries, 0 to 434144
# Data columns (total 83 columns):
# Turbine_ID                     434145 non-null object
# Timestamp                      434145 non-null object
# Gen_RPM_Max                    434145 non-null float64
# Gen_RPM_Min                    434145 non-null float64
# Gen_RPM_Avg                    434145 non-null float64
# Gen_RPM_Std                    434145 non-null float64
# Gen_Bear_Temp_Avg              434138 non-null float64
# Gen_Phase1_Temp_Avg            434145 non-null int64
# Gen_Phase2_Temp_Avg            434145 non-null int64
# Gen_Phase3_Temp_Avg            434145 non-null int64
# Hyd_Oil_Temp_Avg               434145 non-null int64
# Gear_Oil_Temp_Avg              434145 non-null int64
# Gear_Bear_Temp_Avg             434145 non-null int64
# Nac_Temp_Avg                   434145 non-null int64
# Rtr_RPM_Max                    434145 non-null float64
# ...

# %%
signals.describe()
# Out:
#          Gen_RPM_Max    Gen_RPM_Min    Gen_RPM_Avg    Gen_RPM_Std  \
# count  434145.000000  434145.000000  434145.000000  434145.000000
# mean     1180.310084     923.317963    1055.186079      68.819458
# std       642.006443     614.935372     617.817715     112.115169
# min         0.000000       0.000000       0.000000       0.000000
# 25%       303.700000     183.900000     261.400000      14.000000
# 50%      1421.100000    1231.300000    1276.800000      28.500000
# 75%      1681.900000    1369.400000    1592.300000      70.800000
# max      2040.900000    1672.000000    1684.400000     823.200000
#
#        Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# count      434138.000000        434145.000000        434145.000000
# mean           47.068879            64.429142            64.082938
# std            17.601409            28.603491            27.594479
# min            12.000000            14.000000            14.000000
# ...

# %%
signals.isna().sum()[signals.isna().sum()>0]
# Out:
# Gen_Bear_Temp_Avg      7
# Grd_Prod_CosPhi_Avg    7
# dtype: int64

# %% [markdown]
# # failures

# %%
failures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
# Turbine_ID    23 non-null object
# Component     23 non-null object
# Timestamp     23 non-null object
# Remarks       23 non-null object
# dtypes: object(4)
# memory usage: 864.0+ bytes

# %%
failures.describe()
# Out:
#        Turbine_ID  Component                  Timestamp             Remarks
# count          23         23                         23                  23
# unique          5          5                         23                  19
# top           T06  GENERATOR  2016-03-03T19:00:00+00:00  Oil leakage in Hub
# freq            7          7                          1                   2

# %%
failures.isna().sum()[failures.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # logs

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256231 entries, 0 to 256230
# Data columns (total 5 columns):
# TimeDetected            256231 non-null object
# TimeReset               1713 non-null object
# UnitTitle               256231 non-null object
# Remark                  256231 non-null object
# UnitTitleDestination    0 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 9.8+ MB

# %%
logs.isna().sum()
# Out:
# TimeDetected                 0
# TimeReset               254518
# UnitTitle                    0
# Remark                       0
# UnitTitleDestination    256231
# dtype: int64

# %% [markdown]
# # metmast

# %%
metmast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69961 entries, 0 to 69960
# Data columns (total 41 columns):
# Timestamp                     69961 non-null object
# Min_Windspeed1                69960 non-null float64
# Max_Windspeed1                69961 non-null float64
# Avg_Windspeed1                69960 non-null float64
# Var_Windspeed1                69960 non-null float64
# Min_Windspeed2                69960 non-null float64
# Max_Windspeed2                69961 non-null float64
# Avg_Windspeed2                69960 non-null float64
# Var_Windspeed2                69960 non-null float64
# Min_Winddirection2            69960 non-null float64
# Max_Winddirection2            69961 non-null int64
# Avg_Winddirection2            69960 non-null float64
# Var_Winddirection2            69958 non-null float64
# Min_AmbientTemp               69960 non-null float64
# Max_AmbientTemp               69961 non-null int64
# Avg_AmbientTemp               69960 non-null float64
# ...

# %%
metmast.describe()
# Out:
#        Min_Windspeed1  Max_Windspeed1  Avg_Windspeed1  Var_Windspeed1  \
# count    69960.000000    69961.000000    69960.000000    69960.000000
# mean         4.245343        8.413618        6.338668        0.926280
# std          2.654873        4.808946        3.733035        1.213568
# min          0.000000        0.000000        0.000000        0.000000
# 25%          2.300000        4.700000        3.500000        0.150000
# 50%          3.700000        7.500000        5.600000        0.480000
# 75%          5.800000       11.300000        8.500000        1.190000
# max         17.800000       30.800000       23.100000       35.100000
#
#        Min_Windspeed2  Max_Windspeed2  Avg_Windspeed2  Var_Windspeed2  \
# count    69960.000000    69961.000000    69960.000000    69960.000000
# mean         4.341732        8.317262        6.338642        0.807165
# std          2.796495        4.693258        3.740070        0.998506
# ...

# %%
metmast.isna().sum()[metmast.isna().sum()>0]
# Out:
# Min_Windspeed1        1
# Avg_Windspeed1        1
# Var_Windspeed1        1
# Min_Windspeed2        1
# Avg_Windspeed2        1
# Var_Windspeed2        1
# Min_Winddirection2    1
# Avg_Winddirection2    1
# Var_Winddirection2    3
# Min_AmbientTemp       1
# Avg_AmbientTemp       1
# Min_Pressure          1
# Avg_Pressure          1
# Min_Humidity          1
# Avg_Humidity          1
# dtype: int64
